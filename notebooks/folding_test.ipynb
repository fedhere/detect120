# %%
import numpy as np
import pylab as pl
# %pylab inline
from scipy import signal
from simulate_and_fold import sim_wave, folding_test
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# default case: 120 Hz sine wave
folding_test()

# %%
# test case: 10 Hz sine wave
folding_test(s_freq=10)

# %%
# test case: 119.75 Hz sine wave
folding_test(s_freq=119.75)

# %%
# test case: 120 Hz square wave
folding_test(w_type='square')

# %%
# test case: 10 Hz square wave
folding_test(w_type='square', s_freq=10)

# %%
# test case: 119.75 Hz square wave
folding_test(w_type='square', s_freq=119.75)
